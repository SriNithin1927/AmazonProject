# %%
import pandas as pd

# %%
import csv
import itertools
from datetime import datetime as dt
from datetime import date

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
cd Downloads
# Out:
# C:\Users\HP\Downloads

# %%
df1=pd.read_csv('Product Sales.csv')
df2=pd.read_csv('Customers Table.csv', dtype={'phone_no':'str','Zipcode':'str'})
df3=pd.read_csv('Customer Age.csv',)

# %%
df1
# Out:
#      Sale_ID Product_ID  Customer_ID Date_of_Purchase     Brand     Category  \
# 0          1        E01            2       2021-01-04    iPhone  Electronics
# 1          2        E02            7       2020-12-18   Samsung  Electronics
# 2          3        E03            9       2020-11-11   Samsung  Electronics
# 3          4        E04           22       2020-11-07   OnePlus  Electronics
# 4          5        E05           15       2020-04-08   OnePlus  Electronics
# ..       ...        ...          ...              ...       ...          ...
# 403      404        F03           34       2019-11-20   Calippo        Foods
# 404      405        F06            4       2019-10-23   Nutella        Foods
# 405      406        F01            9       2020-09-18  Cornetto        Foods
# 406      407        F10           84       2021-04-15    McCain        Foods
# 407      408        F07           88       2020-01-01     Lay's        Foods
#
# ...

# %%
df2
# Out:
#     Customer_id Prefix first_name  Last_name  Gender_id    phone_no  \
# 0             1     Mr    Saurabh   Narvekar          1  7845959657
# 1            43     Mr      rahul      gowda          1           0
# 2            47     Mr      sunil                     1  9834562345
# 3            16              Abhi    Pushkar          3  9275642185
# 4            75    Mrs     Nayana      Patil          2  8974563210
# ..          ...    ...        ...        ...        ...         ...
# 95           97    Mrs     Sruthi     Tumula          2  9872981793
# 96           98     Mr     Mourya     Velchu          1  9832987373
# 97          100     Mr     Mahesh  Veermalla          1  8997897897
# 98           35     Mr    Harshan         PP          1  8869587744
# 99           54              Diya       Bala          3  9856712365
#
#                  email_id Prime_subscription                       Address  \
# ...

# %% [markdown]
# ###

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    2001-01-01
# 1               2            2      Aryan                1989-08-09
# 2               3            3       Siya      Hirani    1996-08-02
# 3               4            4      Aarti  Khandelwal    1969-02-06
# 4               5            5      Adnan         Ali    2002-05-30
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    2001-06-16
# 96             97           97     Sruthi      Tumula    1995-09-19
# 97             98           98     Mourya      Velchu    2000-04-05
# 98             99           99  Avanthika    Velchuri    1996-09-06
# 99            100          100     Mahesh   Veermalla    1993-05-25
#
# [100 rows x 5 columns]

# %%
df3['Date_of_Birth']= pd.to_datetime(df3['Date_of_Birth']).dt.strftime("%Y-%m-%d")
df1['Date_of_Purchase']= pd.to_datetime(df1['Date_of_Purchase']).dt.strftime("%Y-%m-%d")

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    2001-01-01
# 1               2            2      Aryan                1989-08-09
# 2               3            3       Siya      Hirani    1996-08-02
# 3               4            4      Aarti  Khandelwal    1969-02-06
# 4               5            5      Adnan         Ali    2002-05-30
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    2001-06-16
# 96             97           97     Sruthi      Tumula    1995-09-19
# 97             98           98     Mourya      Velchu    2000-04-05
# 98             99           99  Avanthika    Velchuri    1996-09-06
# 99            100          100     Mahesh   Veermalla    1993-05-25
#
# [100 rows x 5 columns]

# %%
df1
# Out:
#      Sale_ID Product_ID  Customer_ID Date_of_Purchase     Brand     Category  \
# 0          1        E01            2       2021-01-04    iPhone  Electronics
# 1          2        E02            7       2020-12-18   Samsung  Electronics
# 2          3        E03            9       2020-11-11   Samsung  Electronics
# 3          4        E04           22       2020-11-07   OnePlus  Electronics
# 4          5        E05           15       2020-04-08   OnePlus  Electronics
# ..       ...        ...          ...              ...       ...          ...
# 403      404        F03           34       2019-11-20   Calippo        Foods
# 404      405        F06            4       2019-10-23   Nutella        Foods
# 405      406        F01            9       2020-09-18  Cornetto        Foods
# 406      407        F10           84       2021-04-15    McCain        Foods
# 407      408        F07           88       2020-01-01     Lay's        Foods
#
# ...

# %%
for i in df3['Date_of_Birth']:
    y=i[0:4]
    t=date.today()
    if(t.year<int(y)):
        y=str(int(y)-100)
        x=y+i[4:]
        df3['Date_of_Birth']=df3['Date_of_Birth'].replace([i],x)

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    2001-01-01
# 1               2            2      Aryan                1989-08-09
# 2               3            3       Siya      Hirani    1996-08-02
# 3               4            4      Aarti  Khandelwal    1969-02-06
# 4               5            5      Adnan         Ali    2002-05-30
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    2001-06-16
# 96             97           97     Sruthi      Tumula    1995-09-19
# 97             98           98     Mourya      Velchu    2000-04-05
# 98             99           99  Avanthika    Velchuri    1996-09-06
# 99            100          100     Mahesh   Veermalla    1993-05-25
#
# [100 rows x 5 columns]

# %%
for i in df1:
    df1[i].fillna(" ",inplace= True)

for i in df2:
    if (i=='phone_no') or (i=='Zipcode'):
        df2[i].fillna("0",inplace= True)
        continue
    df2[i].fillna(" ",inplace= True)

for i in df3:
    df3[i].fillna(" ",inplace= True)

# %%
df1
# Out:
#      Sale_ID Product_ID  Customer_ID Date_of_Purchase     Brand     Category  \
# 0          1        E01            2       2021-01-04    iPhone  Electronics
# 1          2        E02            7       2020-12-18   Samsung  Electronics
# 2          3        E03            9       2020-11-11   Samsung  Electronics
# 3          4        E04           22       2020-11-07   OnePlus  Electronics
# 4          5        E05           15       2020-04-08   OnePlus  Electronics
# ..       ...        ...          ...              ...       ...          ...
# 403      404        F03           34       2019-11-20   Calippo        Foods
# 404      405        F06            4       2019-10-23   Nutella        Foods
# 405      406        F01            9       2020-09-18  Cornetto        Foods
# 406      407        F10           84       2021-04-15    McCain        Foods
# 407      408        F07           88       2020-01-01     Lay's        Foods
#
# ...

# %%
df2
# Out:
#     Customer_id Prefix first_name  Last_name  Gender_id    phone_no  \
# 0             1     Mr    Saurabh   Narvekar          1  7845959657
# 1            43     Mr      rahul      gowda          1           0
# 2            47     Mr      sunil                     1  9834562345
# 3            16              Abhi    Pushkar          3  9275642185
# 4            75    Mrs     Nayana      Patil          2  8974563210
# ..          ...    ...        ...        ...        ...         ...
# 95           97    Mrs     Sruthi     Tumula          2  9872981793
# 96           98     Mr     Mourya     Velchu          1  9832987373
# 97          100     Mr     Mahesh  Veermalla          1  8997897897
# 98           35     Mr    Harshan         PP          1  8869587744
# 99           54              Diya       Bala          3  9856712365
#
#                  email_id Prime_subscription                       Address  \
# ...

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    2001-01-01
# 1               2            2      Aryan                1989-08-09
# 2               3            3       Siya      Hirani    1996-08-02
# 3               4            4      Aarti  Khandelwal    1969-02-06
# 4               5            5      Adnan         Ali    2002-05-30
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    2001-06-16
# 96             97           97     Sruthi      Tumula    1995-09-19
# 97             98           98     Mourya      Velchu    2000-04-05
# 98             99           99  Avanthika    Velchuri    1996-09-06
# 99            100          100     Mahesh   Veermalla    1993-05-25
#
# [100 rows x 5 columns]

# %%
df2.loc[df2.Gender_id == 1, 'Prefix']="Mr"
df2.loc[df2.Gender_id == 2, 'Prefix']="Mrs"

# %%
df1.to_csv('Product Sales.csv',index=False)
df2.to_csv('Customers Table.csv', index=False)
df3.to_csv('Customer Age.csv',index=False)

# %%
df1
# Out:
#      Sale_ID Product_ID  Customer_ID Date_of_Purchase     Brand     Category  \
# 0          1        E01            2       2021-01-04    iPhone  Electronics
# 1          2        E02            7       2020-12-18   Samsung  Electronics
# 2          3        E03            9       2020-11-11   Samsung  Electronics
# 3          4        E04           22       2020-11-07   OnePlus  Electronics
# 4          5        E05           15       2020-04-08   OnePlus  Electronics
# ..       ...        ...          ...              ...       ...          ...
# 403      404        F03           34       2019-11-20   Calippo        Foods
# 404      405        F06            4       2019-10-23   Nutella        Foods
# 405      406        F01            9       2020-09-18  Cornetto        Foods
# 406      407        F10           84       2021-04-15    McCain        Foods
# 407      408        F07           88       2020-01-01     Lay's        Foods
#
# ...

# %%
df2
# Out:
#     Customer_id Prefix first_name  Last_name  Gender_id    phone_no  \
# 0             1     Mr    Saurabh   Narvekar          1  7845959657
# 1            43     Mr      rahul      gowda          1           0
# 2            47     Mr      sunil                     1  9834562345
# 3            16              Abhi    Pushkar          3  9275642185
# 4            75    Mrs     Nayana      Patil          2  8974563210
# ..          ...    ...        ...        ...        ...         ...
# 95           97    Mrs     Sruthi     Tumula          2  9872981793
# 96           98     Mr     Mourya     Velchu          1  9832987373
# 97          100     Mr     Mahesh  Veermalla          1  8997897897
# 98           35     Mr    Harshan         PP          1  8869587744
# 99           54              Diya       Bala          3  9856712365
#
#                  email_id Prime_subscription                       Address  \
# ...

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    2001-01-01
# 1               2            2      Aryan                1989-08-09
# 2               3            3       Siya      Hirani    1996-08-02
# 3               4            4      Aarti  Khandelwal    1969-02-06
# 4               5            5      Adnan         Ali    2002-05-30
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    2001-06-16
# 96             97           97     Sruthi      Tumula    1995-09-19
# 97             98           98     Mourya      Velchu    2000-04-05
# 98             99           99  Avanthika    Velchuri    1996-09-06
# 99            100          100     Mahesh   Veermalla    1993-05-25
#
# [100 rows x 5 columns]
