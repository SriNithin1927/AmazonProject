# %%
import pandas as pd

# %%
import csv
from datetime import datetime as dt
from datetime import date

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
cd Downloads
# Out:
# C:\Users\HP\Downloads

# %%
df=pd.read_csv('Products .csv')

# %%
df.head()
# Out:
#   Product_ID(PK)     Brand     Category Sub Category            Product_Name  \
# 0            E01    iphone  Electronics        Phone        Apple iPhone 12
# 1            E02  Samsung   Electronics        Phone  Samsung Galaxy M53 5G
# 2            E03  Samsung   Electronics        Phone     Samsung Galaxy M13
# 3            E04   OnePlus  Electronics        Phone        OnePlus 10T 5G
# 4            E05   OnePlus  Electronics        Phone      OnePlus 10 Pro 5G
#
#    Price
# 0  59000
# 1  32999
# 2  14999
# 3  49999
# 4  71999

# %%
df1=pd.read_csv('Product Sales.csv')
df2=pd.read_csv('Customers Table.csv', dtype={'phone_no':'str','Zipcode':'str'})
df3=pd.read_csv('Customer Age.csv',)

# %%
df
# Out:
#    Product_ID(PK)       Brand     Category Sub Category  \
# 0             E01      iphone  Electronics        Phone
# 1             E02    Samsung   Electronics        Phone
# 2             E03    Samsung   Electronics        Phone
# 3             E04     OnePlus  Electronics        Phone
# 4             E05     OnePlus  Electronics        Phone
# ..            ...         ...          ...          ...
# 95            F16  Hellmann's         Food    Dressings
# 96            F17      Bovril         Food      Savoury
# 97            F18       Knorr         Food      Savoury
# 98            F19  Pot Noodle         Food      Savoury
# 99            F20  Hellmann's         Food    Dressings
#
#                                Product_Name  Price
# 0                          Apple iPhone 12   59000
# 1                    Samsung Galaxy M53 5G   32999
# 2                       Samsung Galaxy M13   14999
# 3                          OnePlus 10T 5G    49999
# ...

# %%
df1
# Out:
#      Sale_ID Product_ID  Customer_ID Date_of_Purchase     Brand     Category  \
# 0          1        E01            2       01-04-2021    iPhone  Electronics
# 1          2        E02            7       18-12-2020   Samsung  Electronics
# 2          3        E03            9              NaN   Samsung  Electronics
# 3          4        E04           22       11-07-2020   OnePlus  Electronics
# 4          5        E05           15       04-08-2020   OnePlus  Electronics
# ..       ...        ...          ...              ...       ...          ...
# 403      404        F03           34       20-11-2019   Calippo        Foods
# 404      405        F06            4       23-10-2019   Nutella        Foods
# 405      406        F01            9       18-09-2020  Cornetto        Foods
# 406      407        F10           84       15-04-2021    McCain        Foods
# 407      408        F07           88       01-01-2020     Lay's        Foods
#
# ...

# %%
df2
# Out:
#     Customer_id Prefix first_name   Last_name  Gender_id    phone_no  \
# 0             1     Mr    Saurabh    Narvekar          1  7845959657
# 1             2     Mr      Aryan         NaN          1  9357285326
# 2             3    Mrs       Siya      Hirani          2         NaN
# 3             4     Ms      Aarti  Khandelwal          2  7689546246
# 4             5     Mr      Adnan         Ali          1  9857643562
# ..          ...    ...        ...         ...        ...         ...
# 95           96     Mr     Jeremy      Brandi          1  8971879792
# 96           97     Ms     Sruthi      Tumula          2  9872981793
# 97           98     Mr     Mourya      Velchu          1  9832987373
# 98           99     Ms  Avanthika    Velchuri          2  8293712973
# 99          100     Mr     Mahesh   Veermalla          1  8997897897
#
#                   email_id Prime_subscription                       Address  \
# ...

# %% [markdown]
# ###

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar      1-1-2001
# 1               2            2      Aryan         NaN        8-9-89
# 2               3            3       Siya      Hirani        8/2/96
# 3               4            4      Aarti  Khandelwal        2/6/69
# 4               5            5      Adnan         Ali     30/5/2002
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    16/06/2001
# 96             97           97     Sruthi      Tumula     19/9/1995
# 97             98           98     Mourya      Velchu    04/05/2000
# 98             99           99  Avanthika    Velchuri    09/06/1996
# 99            100          100     Mahesh   Veermalla     25/5/1993
#
# [100 rows x 5 columns]

# %%
df3['Date_of_Birth']= pd.to_datetime(df3['Date_of_Birth']).dt.strftime("%d-%m-%Y")
df1['Date_of_Purchase']= pd.to_datetime(df1['Date_of_Purchase']).dt.strftime("%d-%m-%Y")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23252\3469199592.py:1: UserWarning: Parsing '23/12/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df3['Date_of_Birth']= pd.to_datetime(df3['Date_of_Birth']).dt.strftime("%d-%m-%Y")
# C:\Users\HP\AppData\Local\Temp\ipykernel_23252\3469199592.py:1: UserWarning: Parsing '21/01/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df3['Date_of_Birth']= pd.to_datetime(df3['Date_of_Birth']).dt.strftime("%d-%m-%Y")
# C:\Users\HP\AppData\Local\Temp\ipykernel_23252\3469199592.py:1: UserWarning: Parsing '14/05/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df3['Date_of_Birth']= pd.to_datetime(df3['Date_of_Birth']).dt.strftime("%d-%m-%Y")
# ...

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    01-01-2001
# 1               2            2      Aryan         NaN    09-08-1989
# 2               3            3       Siya      Hirani    02-08-1996
# 3               4            4      Aarti  Khandelwal    06-02-2069
# 4               5            5      Adnan         Ali    30-05-2002
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    16-06-2001
# 96             97           97     Sruthi      Tumula    19-09-1995
# 97             98           98     Mourya      Velchu    05-04-2000
# 98             99           99  Avanthika    Velchuri    06-09-1996
# 99            100          100     Mahesh   Veermalla    25-05-1993
#
# [100 rows x 5 columns]

# %%
df=df.dropna()
df1=df1.dropna()
df2=df2.dropna()
df3=df3.dropna()

# %%
df
# Out:
#    Product_ID(PK)       Brand     Category Sub Category  \
# 0             E01      iphone  Electronics        Phone
# 1             E02    Samsung   Electronics        Phone
# 2             E03    Samsung   Electronics        Phone
# 3             E04     OnePlus  Electronics        Phone
# 4             E05     OnePlus  Electronics        Phone
# ..            ...         ...          ...          ...
# 95            F16  Hellmann's         Food    Dressings
# 96            F17      Bovril         Food      Savoury
# 97            F18       Knorr         Food      Savoury
# 98            F19  Pot Noodle         Food      Savoury
# 99            F20  Hellmann's         Food    Dressings
#
#                                Product_Name  Price
# 0                          Apple iPhone 12   59000
# 1                    Samsung Galaxy M53 5G   32999
# 2                       Samsung Galaxy M13   14999
# 3                          OnePlus 10T 5G    49999
# ...

# %%
df1
# Out:
#      Sale_ID Product_ID  Customer_ID Date_of_Purchase     Brand     Category  \
# 0          1        E01            2       04-01-2021    iPhone  Electronics
# 1          2        E02            7       18-12-2020   Samsung  Electronics
# 3          4        E04           22       07-11-2020   OnePlus  Electronics
# 4          5        E05           15       08-04-2020   OnePlus  Electronics
# 5          6        E06           17       09-05-2021   OnePlus  Electronics
# ..       ...        ...          ...              ...       ...          ...
# 403      404        F03           34       20-11-2019   Calippo        Foods
# 404      405        F06            4       23-10-2019   Nutella        Foods
# 405      406        F01            9       18-09-2020  Cornetto        Foods
# 406      407        F10           84       15-04-2021    McCain        Foods
# 407      408        F07           88       01-01-2020     Lay's        Foods
#
# ...

# %%
df2
# Out:
#     Customer_id Prefix   first_name       Last_name  Gender_id    phone_no  \
# 0             1     Mr      Saurabh        Narvekar          1  7845959657
# 5             6     Mr    Dheeshith              CP          1  9658745896
# 7             8     Mr        Mihir            Jain          1  8765936572
# 8             9     Mr       Pramod               N          1  7441967681
# 11           12    Mrs        Smija            Hari          2  7855896416
# 12           13     Ms       Udhav           Thakre          1  8945745613
# 14           15    Mrs     Mridhula              CK          2  9696733256
# 17           18     Mr       Sakshi           Joshi          2  1548268973
# 18           19    Mrs       Meghna         Poduval          2  9485896325
# 20           21     Mr      Hritik           Roshan          1  7889456512
# 21           22     Mr      Midhun             John          1  9696584525
# ...

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    01-01-2001
# 2               3            3       Siya      Hirani    02-08-1996
# 3               4            4      Aarti  Khandelwal    06-02-2069
# 4               5            5      Adnan         Ali    30-05-2002
# 5               6            6  Dheeshith          CP    17-05-1963
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    16-06-2001
# 96             97           97     Sruthi      Tumula    19-09-1995
# 97             98           98     Mourya      Velchu    05-04-2000
# 98             99           99  Avanthika    Velchuri    06-09-1996
# 99            100          100     Mahesh   Veermalla    25-05-1993
#
# [87 rows x 5 columns]

# %%
for i in df3['Date_of_Birth']:
    y=i[-4:]
    t=date.today()
    if(t.year<int(y)):
        y=str(int(y)-100)
        x=i[:-4]+y
        df3['Date_of_Birth']=df3['Date_of_Birth'].replace([i],x)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23252\334788629.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Date_of_Birth']=df3['Date_of_Birth'].replace([i],x)

# %%
df3
# Out:
#     Person_Id(PK)  Customer_id first_name   Last_name Date_of_Birth
# 0               1            1    Saurabh    Narvekar    01-01-2001
# 2               3            3       Siya      Hirani    02-08-1996
# 3               4            4      Aarti  Khandelwal    06-02-1969
# 4               5            5      Adnan         Ali    30-05-2002
# 5               6            6  Dheeshith          CP    17-05-1963
# ..            ...          ...        ...         ...           ...
# 95             96           96     Jeremy      Brandi    16-06-2001
# 96             97           97     Sruthi      Tumula    19-09-1995
# 97             98           98     Mourya      Velchu    05-04-2000
# 98             99           99  Avanthika    Velchuri    06-09-1996
# 99            100          100     Mahesh   Veermalla    25-05-1993
#
# [87 rows x 5 columns]

# %%
for i in df3['Date_of_Birth']:
    print(i)
# Out:
# 01-01-2001
# 02-08-1996
# 06-02-1969
# 30-05-2002
# 17-05-1963
# 08-02-2003
# 08-02-2000
# 08-02-1980
# 09-01-2001
# 04-07-1989
# 01-02-1969
# 12-04-1989
# 18-02-1969
# 03-01-1993
# 11-12-2000
# 11-11-1999
# 02-11-1979
# 14-04-1971
# 09-12-2000
# 23-12-2002
# 21-01-2004
# 03-01-1999
# 14-05-1997
# 08-09-1995
# 01-11-1997
# 29-09-2000
# 28-02-1999
# 19-01-2001
# 23-03-1995
# 13-06-1998
# 03-01-1999
# 17-05-1997
# 15-12-2001
# 28-02-1999
# 05-09-2001
# 05-03-2000
# 11-02-2009
# 08-12-2004
# 02-02-1995
# 08-02-1999
# 22-05-1990
# 10-02-1999
# 23-11-1995
# 16-06-2001
# 03-12-1998
# 14-10-1998
# 15-08-1990
# 18-06-1994
# 12-12-2000
# 13-03-2000
# 22-12-1999
# 23-05-1990
# 05-04-1996
# 23-02-1998
# 06-05-2000
# 05-09-1999
# 09-04-2000
# 01-01-1999
# 14-08-1997
# 07-07-1994
# 17-07-1997
# 02-09-1992
# 02-02-2000
# 07-08-1999
# 22-02-1999
# 16-06-2001
# 19-09-1995
# 05-04-2000
# 06-09-1996
# 25-05-1993
# 21-02-1995
# 05-05-1990
# 22-03-2005
# 17-05-1992
# 14-09-1995
# 08-12-2002
# ...

# %%
df.to_csv('Products .csv',index=False)
df1.to_csv('Product Sales.csv',index=False)
df2.to_csv('Customers Table.csv', index=False)
df3.to_csv('Customer Age.csv',index=False)
